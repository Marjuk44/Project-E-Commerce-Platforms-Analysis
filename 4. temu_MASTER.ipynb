# %%
import pandas as pd

# %% [markdown]
# ## loading the CSV file for each category of TEMU and merging them

# %%
df1 = pd.read_csv("temu_TOYS&Games.csv")
df2 = pd.read_csv("temu_ELECTRONICS.csv")
df3 = pd.read_csv("temu_BEAUTY_&_HEALTH.csv")
df4 = pd.read_csv("temu_FASHION.csv")
df5 = pd.read_csv("temu_Home_&_Kitchen.csv")

# %%
df_temu = pd.concat([df1,df2,df3,df4,df5], axis=0)
df_temu_final = df_temu.drop(["Unnamed: 0"],axis=1).reset_index(drop=True)

# %%
df_temu_final.to_csv("temu_ALLDATA.csv")

# %%
df_temu_final
# Out:
#      store_id  category_id                                              title  \
# 0           3            5  English Toy Mobile Phone Early Education Enlig...
# 1           3            5  SKMEI Children's Luminous Shiny Fashion Electr...
# 2           3            5  Flying Toy Ball Infrared Induction RC Flying T...
# 3           3            5    SKMEI Children's Girl's Flower Electronic Watch
# 4           3            5  Pocket RC Robot Talking Interactive Dialogue V...
# ..        ...          ...                                                ...
# 495         3            4  1 Pair 8.66"*5.9" Insulation Kitchen Gloves, M...
# 496         3            4  1 Pair Kitchen Silicone Dishwashing Gloves, Cl...
# 497         3            4  1pc Wooden Handle Coffee Grinder Brush, Coffee...
# 498         3            4  1pc 10 Inches Stainless Steel Shower Squeegee,...
# 499         3            4  2pcs Hair Brush, Head Massage Brush, Massager ...
#
# ...
